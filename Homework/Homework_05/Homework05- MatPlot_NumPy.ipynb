# %% [markdown]
# # Homework #5 - MatPlot and NumPy
#
#
#
# #Part 1 Mat Plot Lib
#
# Using Matplotlib create the following graphs

# %%
# Imports Here
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
#Example datas
data = np.random.randint(1, 100, 50)
x = np.linspace(1, 10, 50)
y = np.sin(x) * 10 + np.random.randint(-5, 5, 50)
categories = ['Barbarian', 'Sorceress', 'Necromancer', 'Paladin', 'Amazon']
category_values = np.random.randint(10, 100, len(categories))

# %%
# Histogram
plt.figure()
plt.hist(data, bins=10, alpha=0.7, color='blue', edgecolor='black')
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Line Plot
plt.figure()
plt.plot(x, y, marker='o', linestyle='-', color='red', label='Battle Score')
plt.title('Line Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Scatter Plot
plt.figure()
plt.scatter(x, y, color='green', label='Battle Data')
plt.title('Scatter Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Pie Chart
plt.figure()
plt.pie(category_values, labels=categories, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart')
plt.show()

# %%
# Area Plot
plt.figure()
plt.fill_between(x, y, color='skyblue', alpha=0.5)
plt.title('Area Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.grid(True)
plt.show()

# %%
# 3d Plot - Bar Plot
plt.figure()
plt.bar(x[:10], y[:10], color='purple', alpha=0.7)
plt.title('3D Bar Plot (2D View)')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)
plt.show()

# %% [markdown]
# # Part 2 - Num Py
# Like a dictionary, we can create a structured array in Numpy
#
# ```python
# data = np.array([
#     ("Billy", 32, 6),
#     ("Bob", 15, 20),
#     ("Jo", 80, 100),
#     ("Goku", 38, 9001),],
#     dtype=[("name", str, 10),
#            ("age", int),
#            ("power", int)])
# ```
#
# Using the following file https://www.kaggle.com/datasets/gregorut/videogamesales
#
# Create and sort the data by Name, Year, and NA_Sales
#
# Do not use pandas
#
# You can use this to help start you on your way
# https://stackoverflow.com/questions/57785790/construct-structured-numpy-array-from-a-file

# %%
import numpy as np

dtype = [('Name', 'U100'), ('Year_of_Release', 'i4'), ('NA_Sales', 'f4')]

valid_rows = []
with open("vgsales.csv", "r", encoding="utf-8") as f:
    next(f)  # Skip the header row
    for line in f:
        parts = line.strip().split(",")

        # Ensure the row has at least 5 columns before extracting needed values
        if len(parts) >= 5:
            name = parts[0].strip()
            
            # Handle Year: Convert to int, default to 0 if missing
            try:
                year = int(parts[1].strip())
            except ValueError:
                year = 0  # Default for missing or non-numeric years
            
            # Handle NA_Sales: Convert to float, default to 0.0 if missing
            try:
                na_sales = float(parts[4].strip())
            except ValueError:
                na_sales = 0.0  # Default for missing sales

            valid_rows.append((name, year, na_sales))

data = np.array(valid_rows, dtype=dtype)

sorted_by_name = np.sort(data, order="Name")  
sorted_by_year = np.sort(data, order="Year_of_Release")
sorted_by_sales = np.sort(data, order="NA_Sales")[::-1]

print("Sorted by Name (First 10):")
print(sorted_by_name[:10])

print("\nSorted by Year (First 10):")
print(sorted_by_year[:10])

print("\nSorted by NA Sales (Top 10):")
print(sorted_by_sales[:10])
# Out:
# [('"Blast Works: Build', 0, 0.) ('"Crouching Tiger', 0, 0.) ('"Ed', 0, 0.)
#  ('"Ed', 0, 0.) ('"Ed', 0, 0.) ('"Flower', 0, 0.) ('"Monsters', 0, 0.)
#  ('"Monsters', 0, 0.) ('"Monsters', 0, 0.)
#  ('"Sakura Wars: So Long', 0, 0.)]
# [('"Blast Works: Build', 0, 0.) ('"Crouching Tiger', 0, 0.) ('"Ed', 0, 0.)
#  ('"Ed', 0, 0.) ('"Ed', 0, 0.) ('"Flower', 0, 0.) ('"Monsters', 0, 0.)
#  ('"Monsters', 0, 0.) ('"Monsters', 0, 0.)
#  ('"Sakura Wars: So Long', 0, 0.)]
# [('Wii Sports', 2006, 41.36) ('Mario Kart Wii', 2008, 15.68)
#  ('Wii Sports Resort', 2009, 15.61) ('Kinect Adventures!', 2010, 15.  )
#  ('New Super Mario Bros. Wii', 2009, 14.44) ('Wii Play', 2006, 13.96)
#  ('New Super Mario Bros.', 2006, 11.28) ('Mario Kart DS', 2005,  9.71)
#  ('Call of Duty: Black Ops', 2010,  9.7 )
#  ('Grand Theft Auto V', 2013,  9.66)]
